# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas

# %%
#!pip list

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#!pip install openpyxl

# %%
df = pd.read_excel('Vika.xlsx', sheet_name='1')

# %%
df
# Out:
#    Модель Тойоты  Год выпуска   Цена Тип коробки передач  Пробег Тип топлива  \
# 0           GT86         2016  16000              Manual   24089      Petrol
# 1           GT86         2017  15995              Manual   18615      Petrol
# 2           GT86         2015  13998              Manual   27469      Petrol
# 3           GT86         2020  27998              Manual     516      Petrol
# 4           GT86         2016  13990              Manual   37999      Petrol
# ..           ...          ...    ...                 ...     ...         ...
# 63         Yaris         2017  12000           Automatic   17409      Hybrid
# 64         Yaris         2018  11395              Manual    7102      Petrol
# 65         Yaris         2019  12795           Automatic   13000      Petrol
# 66         Yaris         2020  12495              Manual    4895      Petrol
# 67         Yaris         2019  11200              Manual   13986      Petrol
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Модель Тойоты        68 non-null     object
#  1   Год выпуска          68 non-null     int64
#  2   Цена                 68 non-null     int64
#  3   Тип коробки передач  68 non-null     object
#  4   Пробег               68 non-null     int64
#  5   Тип топлива          68 non-null     object
#  6   Дорожный налог       68 non-null     int64
#  7   Расход топлива       68 non-null     float64
#  8   Объём двигателя      68 non-null     float64
#  9   Unnamed: 9           0 non-null      float64
#  10  Unnamed: 10          0 non-null      float64
#  11  Unnamed: 11          0 non-null      float64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 6.5+ KB

# %% [markdown]
# Во всех показателях нет пропущенных значений

# %%
df['Год выпуска'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большинство моделей марки Тайота выпущены после 2012 года

# %%
df['Цена'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Цена варьируется от 1000 до 30000 у.е.

# %%
df['Пробег'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большая часть представленных моделей имеет пробег до 40 тыс.км

# %%
df['Дорожный налог'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Самый распространенный дорожный налог 125-150 у.е.

# %%
df['Расход топлива'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Наиболее распространены автомобили с низким расходом топлива

# %%
df['Объём двигателя'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Наиболее распространены модели марки Тойота с объемом двигателя 1,5 и 2,0 литра

# %%
df.describe()
# Out:
#        Год выпуска          Цена         Пробег  Дорожный налог  \
# count    68.000000     68.000000      68.000000       68.000000
# mean   2016.397059  15056.602941   25843.794118      139.264706
# std       4.063451   7225.717507   27709.926365       75.217420
# min    2001.000000    899.000000      10.000000        0.000000
# 25%    2015.000000  10497.250000    5114.000000      125.000000
# 50%    2017.000000  13992.500000   14972.500000      145.000000
# 75%    2019.000000  19625.000000   35477.750000      145.000000
# max    2020.000000  30500.000000  129000.000000      300.000000
#
#        Расход топлива  Объём двигателя  Unnamed: 9  Unnamed: 10  Unnamed: 11
# count       68.000000        68.000000         0.0          0.0          0.0
# mean        53.617647         1.752941         NaN          NaN          NaN
# std         16.668685         0.331199         NaN          NaN          NaN
# min         32.800000         1.000000         NaN          NaN          NaN
# ...

# %% [markdown]
# Минимальный год выпуска выборки - 2001 год, цена - 899 у.е., пробег - 10 км, расход топлива - 32.8 галлон/100 миль, объем двигателя - 1 литр. Также по таблице видны макисмальные и средние значения каждой характеристики.

# %%
# Cheking Missing data
df.isnull().sum()
# Out:
# Модель Тойоты           0
# Год выпуска             0
# Цена                    0
# Тип коробки передач     0
# Пробег                  0
# Тип топлива             0
# Дорожный налог          0
# Расход топлива          0
# Объём двигателя         0
# Unnamed: 9             68
# Unnamed: 10            68
# Unnamed: 11            68
# dtype: int64

# %%
df.dtypes
# Out:
# Модель Тойоты           object
# Год выпуска              int64
# Цена                     int64
# Тип коробки передач     object
# Пробег                   int64
# Тип топлива             object
# Дорожный налог           int64
# Расход топлива         float64
# Объём двигателя        float64
# Unnamed: 9             float64
# Unnamed: 10            float64
# Unnamed: 11            float64
# dtype: object

# %%
#!pip install seaborn

# %%
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std()
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std()
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %%
df = outliers(df)
df.describe()
# Out:
#        Год выпуска          Цена         Пробег  Дорожный налог  \
# count    68.000000     68.000000      68.000000       68.000000
# mean   2016.465002  15056.602941   25519.487447      139.264706
# std       3.827516   7225.717507   26588.760819       75.217420
# min    2004.206706    899.000000      10.000000        0.000000
# 25%    2015.000000  10497.250000    5114.000000      125.000000
# 50%    2017.000000  13992.500000   14972.500000      145.000000
# 75%    2019.000000  19625.000000   35477.750000      145.000000
# max    2020.000000  30500.000000  108973.573213      300.000000
#
#        Расход топлива  Объём двигателя  Unnamed: 9  Unnamed: 10  Unnamed: 11
# count       68.000000        68.000000         0.0          0.0          0.0
# mean        53.617647         1.752941         NaN          NaN          NaN
# std         16.668685         0.331199         NaN          NaN          NaN
# min         32.800000         1.000000         NaN          NaN          NaN
# ...

# %%
df3 = df[['Тип топлива']]
info = []
for column in df3.columns:
        vals = {"col": column,
                "nunique": df3[column].nunique(),
                "unique": df3[column].unique(),
                "type": df3[column].dtype
               }
        info.append(vals)
pd.DataFrame(info).sort_values(by = "col", ascending = False)
# Out:
#            col  nunique                           unique    type
# 0  Тип топлива        4  [Petrol, Other, Hybrid, Diesel]  object

# %%
fm = {'Petrol':0,'Other':1,'Hybrid':2,'Diesel':3}
df['Тип топлива'] = df['Тип топлива'].map(fm)
df
# Out:
#    Модель Тойоты  Год выпуска   Цена Тип коробки передач   Пробег  \
# 0           GT86       2016.0  16000              Manual  24089.0
# 1           GT86       2017.0  15995              Manual  18615.0
# 2           GT86       2015.0  13998              Manual  27469.0
# 3           GT86       2020.0  27998              Manual    516.0
# 4           GT86       2016.0  13990              Manual  37999.0
# ..           ...          ...    ...                 ...      ...
# 63         Yaris       2017.0  12000           Automatic  17409.0
# 64         Yaris       2018.0  11395              Manual   7102.0
# 65         Yaris       2019.0  12795           Automatic  13000.0
# 66         Yaris       2020.0  12495              Manual   4895.0
# 67         Yaris       2019.0  11200              Manual  13986.0
#
#     Тип топлива  Дорожный налог  Расход топлива  Объём двигателя  Unnamed: 9  \
# 0             0             265            36.2              2.0         NaN
# ...

# %%
for col in df:
    print(df['Тип коробки передач'].unique())
# Out:
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']
# ['Manual' 'Automatic' 'Semi-Auto']

# %%
import seaborn as sns
corrmat = dfr.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [markdown]
# Наибольшую корреляцию можно заметить между факторами Год выпуска и Цена, что и логично.

# %%
df.describe()
# Out:
#        Год выпуска          Цена         Пробег  Тип топлива  Дорожный налог  \
# count    68.000000     68.000000      68.000000    68.000000       68.000000
# mean   2016.465002  15056.602941   25519.487447     0.897059      139.264706
# std       3.827516   7225.717507   26588.760819     1.173586       75.217420
# min    2004.206706    899.000000      10.000000     0.000000        0.000000
# 25%    2015.000000  10497.250000    5114.000000     0.000000      125.000000
# 50%    2017.000000  13992.500000   14972.500000     0.000000      145.000000
# 75%    2019.000000  19625.000000   35477.750000     2.000000      145.000000
# max    2020.000000  30500.000000  108973.573213     3.000000      300.000000
#
#        Расход топлива  Объём двигателя  Unnamed: 9  Unnamed: 10  Unnamed: 11
# count       68.000000        68.000000         0.0          0.0          0.0
# mean        53.617647         1.752941         NaN          NaN          NaN
# ...

# %%
# Splitting the dataset into the Training set and Test set
df.shape
# Out:
# (68, 12)

# %%
X = df.iloc[:, [True,False,True,True,True,True,True,True,True,True,True,True]]
y = df['Цена']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
X
# Out:
#    Модель Тойоты   Цена Тип коробки передач   Пробег  Тип топлива  \
# 0           GT86  16000              Manual  24089.0            0
# 1           GT86  15995              Manual  18615.0            0
# 2           GT86  13998              Manual  27469.0            0
# 3           GT86  27998              Manual    516.0            0
# 4           GT86  13990              Manual  37999.0            0
# ..           ...    ...                 ...      ...          ...
# 63         Yaris  12000           Automatic  17409.0            2
# 64         Yaris  11395              Manual   7102.0            0
# 65         Yaris  12795           Automatic  13000.0            0
# 66         Yaris  12495              Manual   4895.0            0
# 67         Yaris  11200              Manual  13986.0            0
#
#     Дорожный налог  Расход топлива  Объём двигателя  Unnamed: 9  Unnamed: 10  \
# 0              265            36.2              2.0         NaN          NaN
# ...

# %%
df3 = df[['Модель Тойоты']]
info = []
for column in df3.columns:
        vals = {"col": column,
                "nunique": df3[column].nunique(),
                "unique": df3[column].unique(),
                "type": df3[column].dtype
               }
        info.append(vals)
pd.DataFrame(info).sort_values(by = "col", ascending = False)
# Out:
#              col  nunique                        unique    type
# 0  Модель Тойоты        4  [GT86, Corolla, RAV4, Yaris]  object

# %%
fm = {'GT86':0,'Corolla':1,'RAV4':2,'Yaris':3}
df['Модель Тойоты'] = df['Модель Тойоты'].map(fm)
df
# Out:
#     Модель Тойоты  Год выпуска   Цена Тип коробки передач   Пробег  \
# 0               0       2016.0  16000              Manual  24089.0
# 1               0       2017.0  15995              Manual  18615.0
# 2               0       2015.0  13998              Manual  27469.0
# 3               0       2020.0  27998              Manual    516.0
# 4               0       2016.0  13990              Manual  37999.0
# ..            ...          ...    ...                 ...      ...
# 63              3       2017.0  12000           Automatic  17409.0
# 64              3       2018.0  11395              Manual   7102.0
# 65              3       2019.0  12795           Automatic  13000.0
# 66              3       2020.0  12495              Manual   4895.0
# 67              3       2019.0  11200              Manual  13986.0
#
#     Тип топлива  Дорожный налог  Расход топлива  Объём двигателя  Unnamed: 9  \
# 0             0             265            36.2              2.0         NaN
# ...

# %%
#!pip install statsmodels

# %%
# Fitting Simple Linear Regression to the Training set (M2)
f1 = ['Год выпуска']

from sklearn.linear_model import LinearRegression
sr = LinearRegression().fit(X_train[f1], y_train)

# Getting parameters
sr.coef_, sr.intercept_
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-358-7942577e257f> in <module>
#       3
#       4 from sklearn.linear_model import LinearRegression
# ----> 5 sr = LinearRegression().fit(X_train[f1], y_train)
#       6
#       7 # Getting parameters
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# ...

# %% [markdown]
# # Multiple Linear Regression

# %%
mr = LinearRegression().fit(X_train, y_train)
mr.score(X_train, y_train).round(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-357-ce0e88016ae8> in <module>
# ----> 1 mr = LinearRegression().fit(X_train, y_train)
#       2 mr.score(X_train, y_train).round(3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...
